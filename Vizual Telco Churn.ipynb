# %%
telko = pd.read_csv('D:/reza/dbimbing DATA SCIENCE/Code/Telco Customer Churn.csv')

# %%
telko.head(15)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
telko.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
telko.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
telko.sort_values(['TotalCharges'])
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# ...          ...     ...            ...     ...        ...     ...
# 6646  8249-THVEC    Male              0     Yes        Yes      51
# 5598  6051-PTVNS  Female              0     Yes        Yes      55
# 3686  5899-MQZZL  Female              0      No         No      13
# 3353  4536-PLEQY    Male              0     Yes         No      12
# 2845  9093-FPDLG  Female              0      No         No      11
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 936           Yes            No             DSL                  Yes  ...
# ...

# %%
telko['TotalCharges'] = telko['TotalCharges'].apply(lambda x:0 if x==' ' else x)

# %%
telko['TotalCharges'] = telko['TotalCharges'].astype(float)

# %%
telko.sort_values(['TotalCharges'])
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# ...          ...     ...            ...     ...        ...     ...
# 2187  8879-XUAHX    Male              0     Yes         No      71
# 5347  9788-HNGUT    Male              0     Yes         No      72
# 6768  9739-JLPQJ  Female              0     Yes        Yes      72
# 4586  7569-NMZYQ  Female              0     Yes        Yes      72
# 4610  2889-FPWRM    Male              0     Yes         No      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3826          Yes               Yes              No  No internet service  ...
# ...

# %%
telko1 = telko.filter(items=('TotalCharges','Churn'))
telko1.head(10)
# Out:
#    TotalCharges Churn
# 0         29.85    No
# 1       1889.50    No
# 2        108.15   Yes
# 3       1840.75    No
# 4        151.65   Yes
# 5        820.50   Yes
# 6       1949.40    No
# 7        301.90    No
# 8       3046.05   Yes
# 9       3487.95    No

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))
sns.barplot(x=telko1.Churn.value_counts().index, y=telko1.Churn.value_counts(),ax=ax[0]).set(xlabel='Churn',ylabel='Total User')
sns.barplot(x=telko1.Churn.value_counts().index, y=telko1.Churn.value_counts(True),ax=ax[1]).set(xlabel='Churn',ylabel='Percentage User')
plt.show()

# %%
tidy_Tcharge = pd.melt(telko1,
                    id_vars='TotalCharges',
                    var_name='cust')

tidy_Tcharge.head()
# Out:
#    TotalCharges   cust value
# 0         29.85  Churn    No
# 1       1889.50  Churn    No
# 2        108.15  Churn   Yes
# 3       1840.75  Churn    No
# 4        151.65  Churn   Yes

# %%
sns.displot(data=telko1, x='TotalCharges', hue='Churn',kind='kde')
plt.show()
