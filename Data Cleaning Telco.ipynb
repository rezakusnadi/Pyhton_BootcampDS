# %%
#import module library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
telco_data = pd.read_csv('D:/reza/dbimbing DATA SCIENCE BISMILLAH/Code/Telco Customer Churn.csv')

# %%
telco_data.head(15)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
#pengecekan null/missing value
telco_data.isnull().sum(axis = 0)
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#pengecekan data types yang sudah di rubah
telco_data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#data transformation tipe data menjadi category
telco_data['SeniorCitizen'] = telco_data['SeniorCitizen'].astype('category')

# %%
#menjadikan 0/1 menjadi No/Yes untuk kolom SeniorCitizen
telco_data['SeniorCitizen'] = telco_data['SeniorCitizen'].apply(lambda x:'No' if x ==0 else 'Yes')

# %%
telco_data.head(5)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#pengecekan kolom TotalCharges dan masih ada data kosong berupa string (space)
dummy = telco_data.sort_values(['TotalCharges'])
dummy.head(15)
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 936   5709-LVOEQ  Female            No     Yes        Yes       0
# 3826  3213-VVOLG    Male            No     Yes        Yes       0
# 4380  2520-SGTTA  Female            No     Yes        Yes       0
# 753   3115-CZMZD    Male            No      No        Yes       0
# 5218  2923-ARZLG    Male            No     Yes        Yes       0
# 3331  7644-OMVMY    Male            No     Yes        Yes       0
# 6754  2775-SEFEE    Male            No      No        Yes       0
# 6670  4075-WKNIU  Female            No     Yes        Yes       0
# 1340  1371-DWPAZ  Female            No     Yes        Yes       0
# 488   4472-LVYGI  Female            No     Yes        Yes       0
# 1082  4367-NUYAO    Male            No     Yes        Yes       0
# 105   6180-YBIQI    Male            No      No         No       5
# 4459  3178-FESZO  Female            No      No         No       1
# ...

# %%
#data transformation TotalCharges (space) menjadi 0
telco_data['TotalCharges'] = telco_data['TotalCharges'].apply(lambda x:0 if x ==' ' else x)

# %%
#perubahan tipe data object menjadi float
telco_data['TotalCharges'] = telco_data['TotalCharges'].astype(float)

# %%
#pengecekan TotalCharges yang sudah di fiil menjadi 0 
dummy = telco_data.sort_values(['TotalCharges'])
dummy.head(15)
# Out:
#       gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 3826    Male            No     Yes        Yes       0          Yes
# 5218    Male            No     Yes        Yes       0          Yes
# 4380  Female            No     Yes        Yes       0          Yes
# 753     Male            No      No        Yes       0          Yes
# 488   Female            No     Yes        Yes       0           No
# 1082    Male            No     Yes        Yes       0          Yes
# 6754    Male            No      No        Yes       0          Yes
# 936   Female            No     Yes        Yes       0          Yes
# 1340  Female            No     Yes        Yes       0           No
# 6670  Female            No     Yes        Yes       0          Yes
# 3331    Male            No     Yes        Yes       0          Yes
# 1654    Male            No     Yes        Yes       1          Yes
# 6489    Male            No      No         No       1          Yes
# ...

# %%
#catagorical data encoding
telco_data_dummies = pd.get_dummies(telco_data)
telco_data_dummies.head(15)
# Out:
#     tenure  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0        1           29.85         29.85              1            0
# 1       34           56.95       1889.50              0            1
# 2        2           53.85        108.15              0            1
# 3       45           42.30       1840.75              0            1
# 4        2           70.70        151.65              1            0
# 5        8           99.65        820.50              1            0
# 6       22           89.10       1949.40              0            1
# 7       10           29.75        301.90              1            0
# 8       28          104.80       3046.05              1            0
# 9       62           56.15       3487.95              0            1
# 10      13           49.95        587.45              0            1
# 11      16           18.95        326.80              0            1
# 12      58          100.35       5681.10              0            1
# ...

# %%
#pengecekan outlier pada kolom tenure
plt.boxplot(telco_data['tenure'])
plt.show()

# %%
#pengecekan outlier pada kolom MonthlyCharges
plt.boxplot(telco_data['MonthlyCharges'])
plt.show()

# %%
#pengecekan outlier pada kolom TotalCharges
plt.boxplot(telco_data['TotalCharges'])
plt.show()

# %%
telco_data_dummies.dtypes
# Out:
# tenure                                     int64
# MonthlyCharges                           float64
# TotalCharges                             float64
# customerID_0002-ORFBO                      uint8
# customerID_0003-MKNFE                      uint8
#                                           ...
# PaymentMethod_Credit card (automatic)      uint8
# PaymentMethod_Electronic check             uint8
# PaymentMethod_Mailed check                 uint8
# Churn_No                                   uint8
# Churn_Yes                                  uint8
# Length: 7091, dtype: object

# %%
#normalization
telco_data["TotalCharges"]= telco_data["TotalCharges"].value_counts(normalize=True)
